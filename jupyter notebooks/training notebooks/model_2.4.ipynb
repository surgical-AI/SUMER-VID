# %% [markdown]
# <img src="files/model_1_outline.png">

# %% [markdown]
# # change log
# ### changing shuffle to False
# ### changing sequence rate 5 -> 20
#
# ## NEW TO THIS EXP: INCREASING GRU UNITS 64 -> 128

# %% [markdown]
# sequence generator shape (corrected) (b, n, w, h, c)

# %%
import os
import glob
import keras

# %%
# Load the TensorBoard notebook extension
# %reload_ext tensorboard
import tensorflow as tf
import datetime

# %%
# from patrice's blogpost
from keras_video import VideoFrameGenerator

# %%
classes = ['suture_throws', 'hand_ties', 'thread_cuts']
classes.sort()
print(classes)
# Out:
# ['hand_ties', 'suture_throws', 'thread_cuts']

# %%
# some global params
SIZE = (100, 100) # height and width of frame pxl by pxl
CHANNELS = 3 # RGB or whatever
NBFRAME = 20 # num frames in sequence 
BS = 8 # Batch size

# %%
# pattern to get videos and classes
glob_pattern='../data_v3_model_2.2/model_data/{classname}/*.avi'

# %%
# # for data augmentation
# data_aug = keras.preprocessing.image.ImageDataGenerator(
#     zoom_range=.1,
#     horizontal_flip=True,
#     rotation_range=8,
#     width_shift_range=.2,
#     height_shift_range=.2)

# %%
# Create video frame generator
train = VideoFrameGenerator(
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    split_val=.33, 
    shuffle=False,
    batch_size=BS,
    target_shape=SIZE,
    nb_channel=CHANNELS,
    use_frame_cache=True)
# Out:
# class hand_ties, validation count: 121, train count: 247
# class suture_throws, validation count: 122, train count: 248
# class thread_cuts, validation count: 121, train count: 248
# Total data: 3 classes for 743 files for train

# %%
# getting validation data
valid = train.get_validation_generator()
# Out:
# Total data: 3 classes for 364 files for validation

# %%
# import keras_video.utils
# keras_video.utils.show_sample(train)

# %%
#valid.files

# %% [markdown]
# ## BUILD CONV NET

# %%
from keras.layers import Conv2D, BatchNormalization, \
    MaxPool2D, GlobalMaxPool2D
def build_mobilenet(shape=(224, 224, 3), nbout=3):
    model = keras.applications.mobilenet.MobileNet(
        include_top=False,
        input_shape=shape,
        weights='imagenet')
    # Keep 9 layers to train﻿﻿
    trainable = 9
    for layer in model.layers[:-trainable]:
        layer.trainable = False
    for layer in model.layers[-trainable:]:
        layer.trainable = True
    output = GlobalMaxPool2D()
    return keras.Sequential([model, output])

# %% [markdown]
# ## Build GRU

# %%
from keras.layers import TimeDistributed, GRU, Dense, Dropout
# Shape (5, 112, 112, 3) 5 - time sequence length 112x112 = height vs width 3 - num channels
def action_model(shape=(5, 112, 112, 3), nbout=3):
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_mobilenet(shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 112, 112, 3) shape
    # KEY = allows you to add a time sequence to a layer one at a time
    model.add(TimeDistributed(convnet, input_shape=shape))
    # here, you can also use GRU or LSTM
    model.add(GRU(128))
    # and finally, we make a decision network
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %% [markdown]
# ## this is where you tell the model how to train - loss function, weight update mechanism

# %%
INSHAPE=(NBFRAME,) + SIZE + (CHANNELS,) # (5, 112, 112, 3)
# action model - GRU set up for Time shifted CNN
model = action_model(INSHAPE, len(classes))

# this is where you tell the model how to train - loss function, weight update mechanism
optimizer = keras.optimizers.Adam(0.001)
model.compile(
    optimizer,
    'categorical_crossentropy',
    metrics=['acc']
)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %% [markdown]
# ## epochs, call backs

# %%
log_dir = "logs/fit/" + '_model_2.4_'+ datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
print('logs for this run are here: {}'.format(log_dir))
# Out:
# logs for this run are here: logs/fit/_model_2.4_20210511-235613

# %%
EPOCHS=100
# create a "chkp" directory before to run that
# because ModelCheckpoint will write models inside
callbacks = [
    keras.callbacks.ReduceLROnPlateau(verbose=1),
    keras.callbacks.ModelCheckpoint(
        'model2_3_1_chkp/weights.{epoch:02d}-{val_loss:.2f}.hdf5',
        verbose=1),
    tensorboard_callback
]

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
model.fit(
    train,
    validation_data=valid,
    verbose=1,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 406s 4s/step - loss: 1.2717 - acc: 0.2824 - val_loss: 1.1261 - val_acc: 0.3250
#
# Epoch 00001: saving model to model2_3_1_chkp\weights.01-1.13.hdf5
# Epoch 2/100
# 92/92 [==============================] - 99s 1s/step - loss: 1.1425 - acc: 0.2817 - val_loss: 1.0989 - val_acc: 0.3389
#
# Epoch 00002: saving model to model2_3_1_chkp\weights.02-1.10.hdf5
# Epoch 3/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.1416 - acc: 0.2761 - val_loss: 1.0988 - val_acc: 0.3389
#
# Epoch 00003: saving model to model2_3_1_chkp\weights.03-1.10.hdf5
# Epoch 4/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.1160 - acc: 0.3121 - val_loss: 1.1026 - val_acc: 0.3250
#
# Epoch 00004: saving model to model2_3_1_chkp\weights.04-1.10.hdf5
# Epoch 5/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.1132 - acc: 0.3221 - val_loss: 1.1055 - val_acc: 0.3389
#
# Epoch 00005: saving model to model2_3_1_chkp\weights.05-1.11.hdf5
# Epoch 6/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1165 - acc: 0.3486 - val_loss: 1.0999 - val_acc: 0.3389
#
# Epoch 00006: saving model to model2_3_1_chkp\weights.06-1.10.hdf5
# Epoch 7/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1043 - acc: 0.3322 - val_loss: 1.0996 - val_acc: 0.3139
#
# Epoch 00007: saving model to model2_3_1_chkp\weights.07-1.10.hdf5
# Epoch 8/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.1030 - acc: 0.3531 - val_loss: 1.0986 - val_acc: 0.3556
#
# Epoch 00008: saving model to model2_3_1_chkp\weights.08-1.10.hdf5
# Epoch 9/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.1099 - acc: 0.3593 - val_loss: 1.0989 - val_acc: 0.3250
#
# Epoch 00009: saving model to model2_3_1_chkp\weights.09-1.10.hdf5
# Epoch 10/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1044 - acc: 0.3144 - val_loss: 1.0987 - val_acc: 0.3250
#
# Epoch 00010: saving model to model2_3_1_chkp\weights.10-1.10.hdf5
# Epoch 11/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1025 - acc: 0.3027 - val_loss: 1.0982 - val_acc: 0.3389
#
# Epoch 00011: saving model to model2_3_1_chkp\weights.11-1.10.hdf5
# Epoch 12/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.1028 - acc: 0.3310 - val_loss: 1.0983 - val_acc: 0.3667
#
# Epoch 00012: saving model to model2_3_1_chkp\weights.12-1.10.hdf5
# Epoch 13/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.1030 - acc: 0.2833 - val_loss: 1.0988 - val_acc: 0.3361
#
# Epoch 00013: saving model to model2_3_1_chkp\weights.13-1.10.hdf5
# Epoch 14/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0997 - acc: 0.3176 - val_loss: 1.0987 - val_acc: 0.3000
#
# Epoch 00014: saving model to model2_3_1_chkp\weights.14-1.10.hdf5
# Epoch 15/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0997 - acc: 0.3381 - val_loss: 1.0987 - val_acc: 0.3389
#
# Epoch 00015: saving model to model2_3_1_chkp\weights.15-1.10.hdf5
# Epoch 16/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1002 - acc: 0.3178 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00016: saving model to model2_3_1_chkp\weights.16-1.10.hdf5
# Epoch 17/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1002 - acc: 0.3052 - val_loss: 1.0987 - val_acc: 0.3389
#
# Epoch 00017: saving model to model2_3_1_chkp\weights.17-1.10.hdf5
# Epoch 18/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0988 - acc: 0.3274 - val_loss: 1.0986 - val_acc: 0.3250
#
# Epoch 00018: saving model to model2_3_1_chkp\weights.18-1.10.hdf5
# Epoch 19/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0997 - acc: 0.3064 - val_loss: 1.0985 - val_acc: 0.3472
#
# Epoch 00019: saving model to model2_3_1_chkp\weights.19-1.10.hdf5
# Epoch 20/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0989 - acc: 0.3150 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00020: saving model to model2_3_1_chkp\weights.20-1.10.hdf5
# Epoch 21/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0999 - acc: 0.2824 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00021: saving model to model2_3_1_chkp\weights.21-1.10.hdf5
# Epoch 22/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0981 - acc: 0.3702 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00022: saving model to model2_3_1_chkp\weights.22-1.10.hdf5
# Epoch 23/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0987 - acc: 0.3205 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00023: saving model to model2_3_1_chkp\weights.23-1.10.hdf5
# Epoch 24/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0993 - acc: 0.3269 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00024: saving model to model2_3_1_chkp\weights.24-1.10.hdf5
# Epoch 25/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0982 - acc: 0.3466 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00025: saving model to model2_3_1_chkp\weights.25-1.10.hdf5
# Epoch 26/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0987 - acc: 0.3063 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00026: saving model to model2_3_1_chkp\weights.26-1.10.hdf5
# Epoch 27/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0994 - acc: 0.3203 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00027: saving model to model2_3_1_chkp\weights.27-1.10.hdf5
# Epoch 28/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0991 - acc: 0.3239 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00028: saving model to model2_3_1_chkp\weights.28-1.10.hdf5
# Epoch 29/100
# 92/92 [==============================] - 98s 1s/step - loss: 1.0990 - acc: 0.3565 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00029: saving model to model2_3_1_chkp\weights.29-1.10.hdf5
# Epoch 30/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0984 - acc: 0.3330 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00030: saving model to model2_3_1_chkp\weights.30-1.10.hdf5
# Epoch 31/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1000 - acc: 0.2796 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00031: saving model to model2_3_1_chkp\weights.31-1.10.hdf5
# Epoch 32/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0983 - acc: 0.3533 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00032: saving model to model2_3_1_chkp\weights.32-1.10.hdf5
# Epoch 33/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0989 - acc: 0.3326 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00033: saving model to model2_3_1_chkp\weights.33-1.10.hdf5
# Epoch 34/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0985 - acc: 0.3579 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00034: saving model to model2_3_1_chkp\weights.34-1.10.hdf5
# Epoch 35/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0977 - acc: 0.3716 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00035: saving model to model2_3_1_chkp\weights.35-1.10.hdf5
# Epoch 36/100
# 92/92 [==============================] - 97s 1s/step - loss: 1.0991 - acc: 0.3097 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00036: saving model to model2_3_1_chkp\weights.36-1.10.hdf5
# Epoch 37/100
# 92/92 [==============================] - 97s 1s/step - loss: 1.0974 - acc: 0.4019 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00037: saving model to model2_3_1_chkp\weights.37-1.10.hdf5
# Epoch 38/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0986 - acc: 0.3429 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00038: saving model to model2_3_1_chkp\weights.38-1.10.hdf5
# Epoch 39/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0975 - acc: 0.3969 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00039: saving model to model2_3_1_chkp\weights.39-1.10.hdf5
# Epoch 40/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0999 - acc: 0.2958 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00040: saving model to model2_3_1_chkp\weights.40-1.10.hdf5
# Epoch 41/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0992 - acc: 0.3271 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00041: saving model to model2_3_1_chkp\weights.41-1.10.hdf5
# Epoch 42/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0993 - acc: 0.3011 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00042: saving model to model2_3_1_chkp\weights.42-1.10.hdf5
# Epoch 43/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0989 - acc: 0.3378 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00043: saving model to model2_3_1_chkp\weights.43-1.10.hdf5
# Epoch 44/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0986 - acc: 0.3483 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00044: saving model to model2_3_1_chkp\weights.44-1.10.hdf5
# Epoch 45/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0979 - acc: 0.3466 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00045: saving model to model2_3_1_chkp\weights.45-1.10.hdf5
# Epoch 46/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0980 - acc: 0.3706 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00046: saving model to model2_3_1_chkp\weights.46-1.10.hdf5
# Epoch 47/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0989 - acc: 0.3384 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00047: saving model to model2_3_1_chkp\weights.47-1.10.hdf5
# Epoch 48/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0979 - acc: 0.3653 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00048: saving model to model2_3_1_chkp\weights.48-1.10.hdf5
# Epoch 49/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0985 - acc: 0.3235 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00049: saving model to model2_3_1_chkp\weights.49-1.10.hdf5
# Epoch 50/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0995 - acc: 0.3166 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00050: saving model to model2_3_1_chkp\weights.50-1.10.hdf5
# Epoch 51/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0984 - acc: 0.3287 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00051: saving model to model2_3_1_chkp\weights.51-1.10.hdf5
# Epoch 52/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0969 - acc: 0.4214 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00052: saving model to model2_3_1_chkp\weights.52-1.10.hdf5
# Epoch 53/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0984 - acc: 0.3299 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00053: saving model to model2_3_1_chkp\weights.53-1.10.hdf5
# Epoch 54/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0976 - acc: 0.3581 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00054: saving model to model2_3_1_chkp\weights.54-1.10.hdf5
# Epoch 55/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0980 - acc: 0.3942 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00055: saving model to model2_3_1_chkp\weights.55-1.10.hdf5
# Epoch 56/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0986 - acc: 0.3228 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00056: saving model to model2_3_1_chkp\weights.56-1.10.hdf5
# Epoch 57/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0981 - acc: 0.3683 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00057: saving model to model2_3_1_chkp\weights.57-1.10.hdf5
# Epoch 58/100
# 92/92 [==============================] - 97s 1s/step - loss: 1.0984 - acc: 0.3409 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00058: saving model to model2_3_1_chkp\weights.58-1.10.hdf5
# Epoch 59/100
# 92/92 [==============================] - 97s 1s/step - loss: 1.0989 - acc: 0.3379 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00059: saving model to model2_3_1_chkp\weights.59-1.10.hdf5
# Epoch 60/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0991 - acc: 0.3201 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00060: saving model to model2_3_1_chkp\weights.60-1.10.hdf5
# Epoch 61/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0991 - acc: 0.3090 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00061: saving model to model2_3_1_chkp\weights.61-1.10.hdf5
# Epoch 62/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0986 - acc: 0.3146 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00062: saving model to model2_3_1_chkp\weights.62-1.10.hdf5
# Epoch 63/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.1002 - acc: 0.2751 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00063: saving model to model2_3_1_chkp\weights.63-1.10.hdf5
# Epoch 64/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0978 - acc: 0.3628 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00064: saving model to model2_3_1_chkp\weights.64-1.10.hdf5
# Epoch 65/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0989 - acc: 0.3312 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00065: saving model to model2_3_1_chkp\weights.65-1.10.hdf5
# Epoch 66/100
# 92/92 [==============================] - 97s 1s/step - loss: 1.0985 - acc: 0.3456 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00066: saving model to model2_3_1_chkp\weights.66-1.10.hdf5
# Epoch 67/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0995 - acc: 0.3148 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00067: saving model to model2_3_1_chkp\weights.67-1.10.hdf5
# Epoch 68/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0983 - acc: 0.3500 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00068: saving model to model2_3_1_chkp\weights.68-1.10.hdf5
# Epoch 69/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0982 - acc: 0.3272 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00069: saving model to model2_3_1_chkp\weights.69-1.10.hdf5
# Epoch 70/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0991 - acc: 0.3132 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00070: saving model to model2_3_1_chkp\weights.70-1.10.hdf5
# Epoch 71/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0993 - acc: 0.3040 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
#
# Epoch 00071: saving model to model2_3_1_chkp\weights.71-1.10.hdf5
# Epoch 72/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0995 - acc: 0.3182 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00072: saving model to model2_3_1_chkp\weights.72-1.10.hdf5
# Epoch 73/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0984 - acc: 0.3408 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00073: saving model to model2_3_1_chkp\weights.73-1.10.hdf5
# Epoch 74/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0992 - acc: 0.2912 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00074: saving model to model2_3_1_chkp\weights.74-1.10.hdf5
# Epoch 75/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0987 - acc: 0.3244 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00075: saving model to model2_3_1_chkp\weights.75-1.10.hdf5
# Epoch 76/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0995 - acc: 0.2924 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00076: saving model to model2_3_1_chkp\weights.76-1.10.hdf5
# Epoch 77/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0988 - acc: 0.3155 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00077: saving model to model2_3_1_chkp\weights.77-1.10.hdf5
# Epoch 78/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0993 - acc: 0.3126 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00078: saving model to model2_3_1_chkp\weights.78-1.10.hdf5
# Epoch 79/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0990 - acc: 0.3356 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00079: saving model to model2_3_1_chkp\weights.79-1.10.hdf5
# Epoch 80/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0978 - acc: 0.3371 - val_loss: 1.0985 - val_acc: 0.3389
# Epoch 00080: saving model to model2_3_1_chkp\weights.80-1.10.hdf5
# Epoch 81/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0980 - acc: 0.3509 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
#
# Epoch 00081: saving model to model2_3_1_chkp\weights.81-1.10.hdf5
# Epoch 82/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0983 - acc: 0.3867 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00082: saving model to model2_3_1_chkp\weights.82-1.10.hdf5
# Epoch 83/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0992 - acc: 0.3085 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00083: saving model to model2_3_1_chkp\weights.83-1.10.hdf5
# Epoch 84/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.0980 - acc: 0.3451 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00084: saving model to model2_3_1_chkp\weights.84-1.10.hdf5
# Epoch 85/100
# 92/92 [==============================] - 97s 1s/step - loss: 1.0977 - acc: 0.3448 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00085: saving model to model2_3_1_chkp\weights.85-1.10.hdf5
# Epoch 86/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0978 - acc: 0.3761 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00086: saving model to model2_3_1_chkp\weights.86-1.10.hdf5
# Epoch 87/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0984 - acc: 0.3329 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00087: saving model to model2_3_1_chkp\weights.87-1.10.hdf5
# Epoch 88/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1001 - acc: 0.2529 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00088: saving model to model2_3_1_chkp\weights.88-1.10.hdf5
# Epoch 89/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0997 - acc: 0.3006 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00089: saving model to model2_3_1_chkp\weights.89-1.10.hdf5
# Epoch 90/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0986 - acc: 0.3321 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00090: saving model to model2_3_1_chkp\weights.90-1.10.hdf5
# Epoch 91/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0982 - acc: 0.3770 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
#
# Epoch 00091: saving model to model2_3_1_chkp\weights.91-1.10.hdf5
# Epoch 92/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0979 - acc: 0.3783 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00092: saving model to model2_3_1_chkp\weights.92-1.10.hdf5
# Epoch 93/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.0984 - acc: 0.3559 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00093: saving model to model2_3_1_chkp\weights.93-1.10.hdf5
# Epoch 94/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0974 - acc: 0.3868 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00094: saving model to model2_3_1_chkp\weights.94-1.10.hdf5
# Epoch 95/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0998 - acc: 0.2568 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00095: saving model to model2_3_1_chkp\weights.95-1.10.hdf5
# Epoch 96/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0986 - acc: 0.3612 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00096: saving model to model2_3_1_chkp\weights.96-1.10.hdf5
# Epoch 97/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0983 - acc: 0.3819 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00097: saving model to model2_3_1_chkp\weights.97-1.10.hdf5
# Epoch 98/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.0986 - acc: 0.3106 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00098: saving model to model2_3_1_chkp\weights.98-1.10.hdf5
# Epoch 99/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.0976 - acc: 0.3847 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00099: saving model to model2_3_1_chkp\weights.99-1.10.hdf5
# Epoch 100/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0979 - acc: 0.3639 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00100: saving model to model2_3_1_chkp\weights.100-1.10.hdf5
