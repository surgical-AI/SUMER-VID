# %%
import ipywidgets as widgets
model_no = widgets.Text(value='4.0')
epochs = widgets.IntSlider(value=300, min=0, max=10000, step=100)
print('Model number')
display(model_no)
print('Epochs')
display(epochs)
# Out:
# Model number
# Text(value='4.0')
# Epochs
# IntSlider(value=300, max=10000, step=100)

# %% [markdown]
# ##### CNN + GRU,
# ##### New: Data augmentation - zoom , horizontal flip, rotation

# %% [markdown]
# sequence generator shape (corrected) (b, n, w, h, c)

# %%
import os
import glob
import keras

# %%
# Load the TensorBoard notebook extension
# %reload_ext tensorboard
import tensorflow as tf
import datetime

# %%
# from patrice's blogpost
from keras_video import VideoFrameGenerator

# %%
classes = ['suture_throws', 'hand_ties', 'thread_cuts']
classes.sort()
print(classes)
# Out:
# ['hand_ties', 'suture_throws', 'thread_cuts']

# %%
# some global params
SIZE = (100, 100) # height and width of frame pxl by pxl
CHANNELS = 3 # RGB or whatever
NBFRAME = 5 # num frames in sequence 
BS = 8 # Batch size

# %%
# pattern to get videos and classes
glob_pattern='../../data_v3_model_2.2/model_data/{classname}/*.avi'

# %%
# for data augmentation
data_aug = keras.preprocessing.image.ImageDataGenerator(
    zoom_range=.1,
    horizontal_flip=True,
    rotation_range=8,
    width_shift_range=.2,
    height_shift_range=.2)

# %%
# Create video frame generator
train = VideoFrameGenerator(
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    split_val=.33, 
    shuffle=False,
    transformation=data_aug,
    batch_size=BS,
    target_shape=SIZE,
    nb_channel=CHANNELS,
    use_frame_cache=True)
# Out:
# class hand_ties, validation count: 121, train count: 247
# class suture_throws, validation count: 122, train count: 248
# class thread_cuts, validation count: 121, train count: 248
# Total data: 3 classes for 743 files for train

# %%
# getting validation data
valid = train.get_validation_generator()
# Out:
# Total data: 3 classes for 364 files for validation

# %%
# import keras_video.utils
# keras_video.utils.show_sample(train)

# %%
#valid.files

# %% [markdown]
# ## BUILD CONV NET

# %%
from keras.layers import Conv2D, BatchNormalization, \
    MaxPool2D, GlobalMaxPool2D
def build_mobilenet(shape=(224, 224, 3), nbout=3):
#     model = keras.applications.mobilenet.MobileNet(
#         include_top=False,
#         input_shape=shape,
#         weights='imagenet')
    
    model = tf.keras.applications.ResNet50(
        include_top=False,
        weights="imagenet",
        #input_tensor=None,
        input_shape=shape,
        pooling=None,
        classes=1000,
    )
    # Keep 9 layers to train﻿﻿
    trainable = 9
    for layer in model.layers[:-trainable]:
        layer.trainable = False
    for layer in model.layers[-trainable:]:
        layer.trainable = True
        
    # adding a max pool
    output = GlobalMaxPool2D()

    return keras.Sequential([model, output])

# %% [markdown]
# ## Build GRU

# %%
from keras.layers import TimeDistributed, GRU, Dense, Dropout
# Shape (5, 112, 112, 3) 5 - time sequence length 112x112 = height vs width 3 - num channels
def action_model(shape=(5, 112, 112, 3), nbout=3):
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_mobilenet(shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 112, 112, 3) shape
    # KEY = allows you to add a time sequence to a layer one at a time
    model.add(TimeDistributed(convnet, input_shape=shape))
    # here, you can also use GRU or LSTM
    model.add(GRU(64))
    # and finally, we make a decision network
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %% [markdown]
# ## this is where you tell the model how to train - loss function, weight update mechanism

# %%
INSHAPE=(NBFRAME,) + SIZE + (CHANNELS,) # (20, 112, 112, 3)
# action model - GRU set up for Time shifted CNN
model = action_model(INSHAPE, len(classes))

# this is where you tell the model how to train - loss function, weight update mechanism
optimizer = keras.optimizers.Adam(0.001)
model.compile(
    optimizer,
    'categorical_crossentropy',
    metrics=['acc']
)

# %% [markdown]
# ## epochs, call backs

# %%
log_dir = "logs/fit/model_{}_".format(model_no.value) + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
print('logs for this run are here: {}'.format(log_dir))
# Out:
# logs for this run are here: logs/fit/model_4.0_20210617-134630

# %%
EPOCHS=epochs.value
print('number of epochs: {}'.format(epochs.value))
model_dir = './model_' + model_no.value + '_chkp/'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
    print('new folder created for new model: {}'.format(model_dir))
    
model_save_path = model_dir + 'weights.{epoch:02d}-{val_loss:.2f}.hdf5'
# Out:
# number of epochs: 300

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(verbose=1),
    keras.callbacks.ModelCheckpoint(
        model_save_path,
        verbose=1),
    tensorboard_callback
]

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
model.fit(
    train,
    validation_data=valid,
    verbose=1,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/300
# 92/92 [==============================] - 269s 3s/step - loss: 1.2457 - acc: 0.3037 - val_loss: 1.1001 - val_acc: 0.3361
#
# Epoch 00001: saving model to ./model_4.0_chkp\weights.01-1.10.hdf5
# Epoch 2/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1148 - acc: 0.3201 - val_loss: 1.1014 - val_acc: 0.3250
#
# Epoch 00002: saving model to ./model_4.0_chkp\weights.02-1.10.hdf5
# Epoch 3/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1051 - acc: 0.3384 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00003: saving model to ./model_4.0_chkp\weights.03-1.10.hdf5
# Epoch 4/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1064 - acc: 0.2739 - val_loss: 1.0994 - val_acc: 0.3250
#
# Epoch 00004: saving model to ./model_4.0_chkp\weights.04-1.10.hdf5
# Epoch 5/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1029 - acc: 0.3346 - val_loss: 1.0985 - val_acc: 0.3389
#
# Epoch 00005: saving model to ./model_4.0_chkp\weights.05-1.10.hdf5
# Epoch 6/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1017 - acc: 0.3269 - val_loss: 1.0990 - val_acc: 0.3389
#
# Epoch 00006: saving model to ./model_4.0_chkp\weights.06-1.10.hdf5
# Epoch 7/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1064 - acc: 0.2862 - val_loss: 1.0986 - val_acc: 0.3389
#
# Epoch 00007: saving model to ./model_4.0_chkp\weights.07-1.10.hdf5
# Epoch 8/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0997 - acc: 0.2513 - val_loss: 1.0987 - val_acc: 0.3250
#
# Epoch 00008: saving model to ./model_4.0_chkp\weights.08-1.10.hdf5
# Epoch 9/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0992 - acc: 0.3020 - val_loss: 1.0986 - val_acc: 0.3361
#
# Epoch 00009: saving model to ./model_4.0_chkp\weights.09-1.10.hdf5
# Epoch 10/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0994 - acc: 0.2879 - val_loss: 1.0986 - val_acc: 0.3389
#
# Epoch 00010: saving model to ./model_4.0_chkp\weights.10-1.10.hdf5
# Epoch 11/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0996 - acc: 0.2118 - val_loss: 1.0986 - val_acc: 0.3389
#
# Epoch 00011: saving model to ./model_4.0_chkp\weights.11-1.10.hdf5
# Epoch 12/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0975 - acc: 0.4476 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00012: saving model to ./model_4.0_chkp\weights.12-1.10.hdf5
# Epoch 13/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0980 - acc: 0.3389 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00013: saving model to ./model_4.0_chkp\weights.13-1.10.hdf5
# Epoch 14/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0994 - acc: 0.3514 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00014: saving model to ./model_4.0_chkp\weights.14-1.10.hdf5
# Epoch 15/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0992 - acc: 0.3330 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00015: saving model to ./model_4.0_chkp\weights.15-1.10.hdf5
# Epoch 16/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0997 - acc: 0.2965 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00016: saving model to ./model_4.0_chkp\weights.16-1.10.hdf5
# Epoch 17/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3036 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00017: saving model to ./model_4.0_chkp\weights.17-1.10.hdf5
# Epoch 18/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0984 - acc: 0.3303 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00018: saving model to ./model_4.0_chkp\weights.18-1.10.hdf5
# Epoch 19/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.1006 - acc: 0.2562 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00019: saving model to ./model_4.0_chkp\weights.19-1.10.hdf5
# Epoch 20/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0975 - acc: 0.3672 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00020: saving model to ./model_4.0_chkp\weights.20-1.10.hdf5
# Epoch 21/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.3261 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00021: saving model to ./model_4.0_chkp\weights.21-1.10.hdf5
# Epoch 22/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3313 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00022: saving model to ./model_4.0_chkp\weights.22-1.10.hdf5
# Epoch 23/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.1000 - acc: 0.2707 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00023: saving model to ./model_4.0_chkp\weights.23-1.10.hdf5
# Epoch 24/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.3231 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00024: saving model to ./model_4.0_chkp\weights.24-1.10.hdf5
# Epoch 25/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0990 - acc: 0.3177 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00025: saving model to ./model_4.0_chkp\weights.25-1.10.hdf5
# Epoch 26/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.3303 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00026: saving model to ./model_4.0_chkp\weights.26-1.10.hdf5
# Epoch 27/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0996 - acc: 0.2874 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00027: saving model to ./model_4.0_chkp\weights.27-1.10.hdf5
# Epoch 28/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0982 - acc: 0.3864 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00028: saving model to ./model_4.0_chkp\weights.28-1.10.hdf5
# Epoch 29/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0979 - acc: 0.3720 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00029: saving model to ./model_4.0_chkp\weights.29-1.10.hdf5
# Epoch 30/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0980 - acc: 0.3743 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00030: saving model to ./model_4.0_chkp\weights.30-1.10.hdf5
# Epoch 31/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3828 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00031: saving model to ./model_4.0_chkp\weights.31-1.10.hdf5
# Epoch 32/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0981 - acc: 0.4150 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00032: saving model to ./model_4.0_chkp\weights.32-1.10.hdf5
# Epoch 33/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0976 - acc: 0.3640 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00033: saving model to ./model_4.0_chkp\weights.33-1.10.hdf5
# Epoch 34/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0984 - acc: 0.3381 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00034: saving model to ./model_4.0_chkp\weights.34-1.10.hdf5
# Epoch 35/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3578 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00035: saving model to ./model_4.0_chkp\weights.35-1.10.hdf5
# Epoch 36/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0986 - acc: 0.3656 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00036: saving model to ./model_4.0_chkp\weights.36-1.10.hdf5
# Epoch 37/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3184 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00037: saving model to ./model_4.0_chkp\weights.37-1.10.hdf5
# Epoch 38/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0993 - acc: 0.3045 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00038: saving model to ./model_4.0_chkp\weights.38-1.10.hdf5
# Epoch 39/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.2791 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00039: saving model to ./model_4.0_chkp\weights.39-1.10.hdf5
# Epoch 40/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0983 - acc: 0.3304 - val_loss: 1.0985 - val_acc: 0.3361
# Epoch 00040: saving model to ./model_4.0_chkp\weights.40-1.10.hdf5
# Epoch 41/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0997 - acc: 0.2930 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00041: saving model to ./model_4.0_chkp\weights.41-1.10.hdf5
# Epoch 42/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0985 - acc: 0.3284 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00042: saving model to ./model_4.0_chkp\weights.42-1.10.hdf5
# Epoch 43/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0994 - acc: 0.3337 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00043: saving model to ./model_4.0_chkp\weights.43-1.10.hdf5
# Epoch 44/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3470 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00044: saving model to ./model_4.0_chkp\weights.44-1.10.hdf5
# Epoch 45/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0981 - acc: 0.3388 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00045: saving model to ./model_4.0_chkp\weights.45-1.10.hdf5
# Epoch 46/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3317 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00046: saving model to ./model_4.0_chkp\weights.46-1.10.hdf5
# Epoch 47/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3221 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00047: saving model to ./model_4.0_chkp\weights.47-1.10.hdf5
# Epoch 48/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0971 - acc: 0.3603 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00048: saving model to ./model_4.0_chkp\weights.48-1.10.hdf5
# Epoch 49/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0977 - acc: 0.3885 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00049: saving model to ./model_4.0_chkp\weights.49-1.10.hdf5
# Epoch 50/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0990 - acc: 0.3097 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00050: saving model to ./model_4.0_chkp\weights.50-1.10.hdf5
# Epoch 51/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0994 - acc: 0.3194 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00051: saving model to ./model_4.0_chkp\weights.51-1.10.hdf5
# Epoch 52/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0990 - acc: 0.3223 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00052: saving model to ./model_4.0_chkp\weights.52-1.10.hdf5
# Epoch 53/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0994 - acc: 0.2950 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00053: saving model to ./model_4.0_chkp\weights.53-1.10.hdf5
# Epoch 54/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0973 - acc: 0.3544 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00054: saving model to ./model_4.0_chkp\weights.54-1.10.hdf5
# Epoch 55/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0999 - acc: 0.3083 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00055: saving model to ./model_4.0_chkp\weights.55-1.10.hdf5
# Epoch 56/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0985 - acc: 0.3328 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00056: saving model to ./model_4.0_chkp\weights.56-1.10.hdf5
# Epoch 57/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0977 - acc: 0.3588 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00057: saving model to ./model_4.0_chkp\weights.57-1.10.hdf5
# Epoch 58/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0972 - acc: 0.3677 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00058: saving model to ./model_4.0_chkp\weights.58-1.10.hdf5
# Epoch 59/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0988 - acc: 0.2900 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00059: saving model to ./model_4.0_chkp\weights.59-1.10.hdf5
# Epoch 60/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0983 - acc: 0.3429 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00060: saving model to ./model_4.0_chkp\weights.60-1.10.hdf5
# Epoch 61/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0977 - acc: 0.3291 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00061: saving model to ./model_4.0_chkp\weights.61-1.10.hdf5
# Epoch 62/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0980 - acc: 0.3422 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00062: saving model to ./model_4.0_chkp\weights.62-1.10.hdf5
# Epoch 63/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0991 - acc: 0.2940 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
#
# Epoch 00063: saving model to ./model_4.0_chkp\weights.63-1.10.hdf5
# Epoch 64/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3530 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00064: saving model to ./model_4.0_chkp\weights.64-1.10.hdf5
# Epoch 65/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0977 - acc: 0.4119 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00065: saving model to ./model_4.0_chkp\weights.65-1.10.hdf5
# Epoch 66/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3369 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00066: saving model to ./model_4.0_chkp\weights.66-1.10.hdf5
# Epoch 67/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0978 - acc: 0.3830 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00067: saving model to ./model_4.0_chkp\weights.67-1.10.hdf5
# Epoch 68/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0968 - acc: 0.3792 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00068: saving model to ./model_4.0_chkp\weights.68-1.10.hdf5
# Epoch 69/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3385 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00069: saving model to ./model_4.0_chkp\weights.69-1.10.hdf5
# Epoch 70/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0999 - acc: 0.2992 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00070: saving model to ./model_4.0_chkp\weights.70-1.10.hdf5
# Epoch 71/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3119 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00071: saving model to ./model_4.0_chkp\weights.71-1.10.hdf5
# Epoch 72/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0979 - acc: 0.3561 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00072: saving model to ./model_4.0_chkp\weights.72-1.10.hdf5
# Epoch 73/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0988 - acc: 0.3201 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
#
# Epoch 00073: saving model to ./model_4.0_chkp\weights.73-1.10.hdf5
# Epoch 74/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3371 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00074: saving model to ./model_4.0_chkp\weights.74-1.10.hdf5
# Epoch 75/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0992 - acc: 0.3084 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00075: saving model to ./model_4.0_chkp\weights.75-1.10.hdf5
# Epoch 76/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3384 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00076: saving model to ./model_4.0_chkp\weights.76-1.10.hdf5
# Epoch 77/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0984 - acc: 0.3252 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00077: saving model to ./model_4.0_chkp\weights.77-1.10.hdf5
# Epoch 78/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0975 - acc: 0.3862 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00078: saving model to ./model_4.0_chkp\weights.78-1.10.hdf5
# Epoch 79/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0978 - acc: 0.3823 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00079: saving model to ./model_4.0_chkp\weights.79-1.10.hdf5
# Epoch 80/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0992 - acc: 0.3106 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00080: saving model to ./model_4.0_chkp\weights.80-1.10.hdf5
# Epoch 81/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3089 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00081: saving model to ./model_4.0_chkp\weights.81-1.10.hdf5
# Epoch 82/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3602 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00082: saving model to ./model_4.0_chkp\weights.82-1.10.hdf5
# Epoch 83/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0983 - acc: 0.3711 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
#
# Epoch 00083: saving model to ./model_4.0_chkp\weights.83-1.10.hdf5
# Epoch 84/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3548 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00084: saving model to ./model_4.0_chkp\weights.84-1.10.hdf5
# Epoch 85/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0990 - acc: 0.3273 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00085: saving model to ./model_4.0_chkp\weights.85-1.10.hdf5
# Epoch 86/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0978 - acc: 0.3913 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00086: saving model to ./model_4.0_chkp\weights.86-1.10.hdf5
# Epoch 87/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0985 - acc: 0.3322 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00087: saving model to ./model_4.0_chkp\weights.87-1.10.hdf5
# Epoch 88/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0980 - acc: 0.3511 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00088: saving model to ./model_4.0_chkp\weights.88-1.10.hdf5
# Epoch 89/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3696 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00089: saving model to ./model_4.0_chkp\weights.89-1.10.hdf5
# Epoch 90/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0977 - acc: 0.3825 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00090: saving model to ./model_4.0_chkp\weights.90-1.10.hdf5
# Epoch 91/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3257 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00091: saving model to ./model_4.0_chkp\weights.91-1.10.hdf5
# Epoch 92/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0990 - acc: 0.2968 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00092: saving model to ./model_4.0_chkp\weights.92-1.10.hdf5
# Epoch 93/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0984 - acc: 0.3227 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
#
# Epoch 00093: saving model to ./model_4.0_chkp\weights.93-1.10.hdf5
# Epoch 94/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0975 - acc: 0.3755 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00094: saving model to ./model_4.0_chkp\weights.94-1.10.hdf5
# Epoch 95/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3473 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00095: saving model to ./model_4.0_chkp\weights.95-1.10.hdf5
# Epoch 96/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0982 - acc: 0.3186 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00096: saving model to ./model_4.0_chkp\weights.96-1.10.hdf5
# Epoch 97/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0994 - acc: 0.3244 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00097: saving model to ./model_4.0_chkp\weights.97-1.10.hdf5
# Epoch 98/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0999 - acc: 0.2935 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00098: saving model to ./model_4.0_chkp\weights.98-1.10.hdf5
# Epoch 99/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.3157 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00099: saving model to ./model_4.0_chkp\weights.99-1.10.hdf5
# Epoch 100/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1004 - acc: 0.2747 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00100: saving model to ./model_4.0_chkp\weights.100-1.10.hdf5
# Epoch 101/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0983 - acc: 0.3774 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00101: saving model to ./model_4.0_chkp\weights.101-1.10.hdf5
# Epoch 102/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3424 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00102: saving model to ./model_4.0_chkp\weights.102-1.10.hdf5
# Epoch 103/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.3194 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 1.0000001044244145e-13.
#
# Epoch 00103: saving model to ./model_4.0_chkp\weights.103-1.10.hdf5
# Epoch 104/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0991 - acc: 0.3224 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00104: saving model to ./model_4.0_chkp\weights.104-1.10.hdf5
# Epoch 105/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3304 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00105: saving model to ./model_4.0_chkp\weights.105-1.10.hdf5
# Epoch 106/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0983 - acc: 0.3235 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00106: saving model to ./model_4.0_chkp\weights.106-1.10.hdf5
# Epoch 107/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0980 - acc: 0.3785 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00107: saving model to ./model_4.0_chkp\weights.107-1.10.hdf5
# Epoch 108/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0974 - acc: 0.3784 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00108: saving model to ./model_4.0_chkp\weights.108-1.10.hdf5
# Epoch 109/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0968 - acc: 0.3824 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00109: saving model to ./model_4.0_chkp\weights.109-1.10.hdf5
# Epoch 110/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0980 - acc: 0.4050 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00110: saving model to ./model_4.0_chkp\weights.110-1.10.hdf5
# Epoch 111/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0997 - acc: 0.3106 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00111: saving model to ./model_4.0_chkp\weights.111-1.10.hdf5
# Epoch 112/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0978 - acc: 0.3824 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00112: saving model to ./model_4.0_chkp\weights.112-1.10.hdf5
# Epoch 113/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0988 - acc: 0.3120 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 1.0000001179769417e-14.
#
# Epoch 00113: saving model to ./model_4.0_chkp\weights.113-1.10.hdf5
# Epoch 114/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3403 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00114: saving model to ./model_4.0_chkp\weights.114-1.10.hdf5
# Epoch 115/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3545 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00115: saving model to ./model_4.0_chkp\weights.115-1.10.hdf5
# Epoch 116/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0982 - acc: 0.3360 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00116: saving model to ./model_4.0_chkp\weights.116-1.10.hdf5
# Epoch 117/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0997 - acc: 0.3028 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00117: saving model to ./model_4.0_chkp\weights.117-1.10.hdf5
# Epoch 118/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0998 - acc: 0.2727 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00118: saving model to ./model_4.0_chkp\weights.118-1.10.hdf5
# Epoch 119/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0977 - acc: 0.3306 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00119: saving model to ./model_4.0_chkp\weights.119-1.10.hdf5
# Epoch 120/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3233 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00120: saving model to ./model_4.0_chkp\weights.120-1.10.hdf5
# Epoch 121/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0976 - acc: 0.3559 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00121: saving model to ./model_4.0_chkp\weights.121-1.10.hdf5
# Epoch 122/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3066 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00122: saving model to ./model_4.0_chkp\weights.122-1.10.hdf5
# Epoch 123/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0971 - acc: 0.3661 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 1.0000001518582595e-15.
#
# Epoch 00123: saving model to ./model_4.0_chkp\weights.123-1.10.hdf5
# Epoch 124/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3338 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00124: saving model to ./model_4.0_chkp\weights.124-1.10.hdf5
# Epoch 125/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0983 - acc: 0.3209 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00125: saving model to ./model_4.0_chkp\weights.125-1.10.hdf5
# Epoch 126/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3507 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00126: saving model to ./model_4.0_chkp\weights.126-1.10.hdf5
# Epoch 127/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.2970 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00127: saving model to ./model_4.0_chkp\weights.127-1.10.hdf5
# Epoch 128/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0977 - acc: 0.3581 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00128: saving model to ./model_4.0_chkp\weights.128-1.10.hdf5
# Epoch 129/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0985 - acc: 0.3438 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00129: saving model to ./model_4.0_chkp\weights.129-1.10.hdf5
# Epoch 130/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3381 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00130: saving model to ./model_4.0_chkp\weights.130-1.10.hdf5
# Epoch 131/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0990 - acc: 0.3344 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00131: saving model to ./model_4.0_chkp\weights.131-1.10.hdf5
# Epoch 132/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3374 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00132: saving model to ./model_4.0_chkp\weights.132-1.10.hdf5
# Epoch 133/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0992 - acc: 0.3064 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 1.0000001095066122e-16.
#
# Epoch 00133: saving model to ./model_4.0_chkp\weights.133-1.10.hdf5
# Epoch 134/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0974 - acc: 0.3852 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00134: saving model to ./model_4.0_chkp\weights.134-1.10.hdf5
# Epoch 135/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0986 - acc: 0.3619 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00135: saving model to ./model_4.0_chkp\weights.135-1.10.hdf5
# Epoch 136/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0976 - acc: 0.3992 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00136: saving model to ./model_4.0_chkp\weights.136-1.10.hdf5
# Epoch 137/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0993 - acc: 0.3066 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00137: saving model to ./model_4.0_chkp\weights.137-1.10.hdf5
# Epoch 138/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1000 - acc: 0.3059 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00138: saving model to ./model_4.0_chkp\weights.138-1.10.hdf5
# Epoch 139/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0983 - acc: 0.3370 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00139: saving model to ./model_4.0_chkp\weights.139-1.10.hdf5
# Epoch 140/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0989 - acc: 0.2949 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00140: saving model to ./model_4.0_chkp\weights.140-1.10.hdf5
# Epoch 141/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0986 - acc: 0.3292 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00141: saving model to ./model_4.0_chkp\weights.141-1.10.hdf5
# Epoch 142/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3718 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00142: saving model to ./model_4.0_chkp\weights.142-1.10.hdf5
# Epoch 143/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0992 - acc: 0.3045 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 1.0000000830368326e-17.
#
# Epoch 00143: saving model to ./model_4.0_chkp\weights.143-1.10.hdf5
# Epoch 144/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0995 - acc: 0.3221 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00144: saving model to ./model_4.0_chkp\weights.144-1.10.hdf5
# Epoch 145/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0991 - acc: 0.3319 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00145: saving model to ./model_4.0_chkp\weights.145-1.10.hdf5
# Epoch 146/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0986 - acc: 0.3881 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00146: saving model to ./model_4.0_chkp\weights.146-1.10.hdf5
# Epoch 147/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3294 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00147: saving model to ./model_4.0_chkp\weights.147-1.10.hdf5
# Epoch 148/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0998 - acc: 0.2916 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00148: saving model to ./model_4.0_chkp\weights.148-1.10.hdf5
# Epoch 149/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0974 - acc: 0.3798 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00149: saving model to ./model_4.0_chkp\weights.149-1.10.hdf5
# Epoch 150/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0973 - acc: 0.3688 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00150: saving model to ./model_4.0_chkp\weights.150-1.10.hdf5
# Epoch 151/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0982 - acc: 0.3635 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00151: saving model to ./model_4.0_chkp\weights.151-1.10.hdf5
# Epoch 152/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0992 - acc: 0.3056 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00152: saving model to ./model_4.0_chkp\weights.152-1.10.hdf5
# Epoch 153/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0967 - acc: 0.4303 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00153: ReduceLROnPlateau reducing learning rate to 1.0000000664932204e-18.
#
# Epoch 00153: saving model to ./model_4.0_chkp\weights.153-1.10.hdf5
# Epoch 154/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0986 - acc: 0.3356 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00154: saving model to ./model_4.0_chkp\weights.154-1.10.hdf5
# Epoch 155/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0990 - acc: 0.3044 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00155: saving model to ./model_4.0_chkp\weights.155-1.10.hdf5
# Epoch 156/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0985 - acc: 0.3384 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00156: saving model to ./model_4.0_chkp\weights.156-1.10.hdf5
# Epoch 157/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0997 - acc: 0.2915 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00157: saving model to ./model_4.0_chkp\weights.157-1.10.hdf5
# Epoch 158/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3365 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00158: saving model to ./model_4.0_chkp\weights.158-1.10.hdf5
# Epoch 159/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0993 - acc: 0.3023 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00159: saving model to ./model_4.0_chkp\weights.159-1.10.hdf5
# Epoch 160/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0994 - acc: 0.3192 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00160: saving model to ./model_4.0_chkp\weights.160-1.10.hdf5
# Epoch 161/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0985 - acc: 0.3118 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00161: saving model to ./model_4.0_chkp\weights.161-1.10.hdf5
# Epoch 162/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0991 - acc: 0.3106 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00162: saving model to ./model_4.0_chkp\weights.162-1.10.hdf5
# Epoch 163/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0992 - acc: 0.3439 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00163: ReduceLROnPlateau reducing learning rate to 1.000000045813705e-19.
#
# Epoch 00163: saving model to ./model_4.0_chkp\weights.163-1.10.hdf5
# Epoch 164/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0994 - acc: 0.3010 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00164: saving model to ./model_4.0_chkp\weights.164-1.10.hdf5
# Epoch 165/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0981 - acc: 0.3247 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00165: saving model to ./model_4.0_chkp\weights.165-1.10.hdf5
# Epoch 166/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0982 - acc: 0.3442 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00166: saving model to ./model_4.0_chkp\weights.166-1.10.hdf5
# Epoch 167/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0991 - acc: 0.3233 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00167: saving model to ./model_4.0_chkp\weights.167-1.10.hdf5
# Epoch 168/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0982 - acc: 0.3490 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00168: saving model to ./model_4.0_chkp\weights.168-1.10.hdf5
# Epoch 169/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0984 - acc: 0.3313 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00169: saving model to ./model_4.0_chkp\weights.169-1.10.hdf5
# Epoch 170/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0975 - acc: 0.3379 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00170: saving model to ./model_4.0_chkp\weights.170-1.10.hdf5
# Epoch 171/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0996 - acc: 0.2782 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00171: saving model to ./model_4.0_chkp\weights.171-1.10.hdf5
# Epoch 172/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0980 - acc: 0.3508 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00172: saving model to ./model_4.0_chkp\weights.172-1.10.hdf5
# Epoch 173/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.3461 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00173: ReduceLROnPlateau reducing learning rate to 1.000000032889008e-20.
#
# Epoch 00173: saving model to ./model_4.0_chkp\weights.173-1.10.hdf5
# Epoch 174/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0978 - acc: 0.3444 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00174: saving model to ./model_4.0_chkp\weights.174-1.10.hdf5
# Epoch 175/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0974 - acc: 0.3699 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00175: saving model to ./model_4.0_chkp\weights.175-1.10.hdf5
# Epoch 176/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0991 - acc: 0.3123 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00176: saving model to ./model_4.0_chkp\weights.176-1.10.hdf5
# Epoch 177/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3392 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00177: saving model to ./model_4.0_chkp\weights.177-1.10.hdf5
# Epoch 178/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0977 - acc: 0.3652 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00178: saving model to ./model_4.0_chkp\weights.178-1.10.hdf5
# Epoch 179/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0976 - acc: 0.3645 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00179: saving model to ./model_4.0_chkp\weights.179-1.10.hdf5
# Epoch 180/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0995 - acc: 0.2872 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00180: saving model to ./model_4.0_chkp\weights.180-1.10.hdf5
# Epoch 181/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0972 - acc: 0.3877 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00181: saving model to ./model_4.0_chkp\weights.181-1.10.hdf5
# Epoch 182/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.2816 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00182: saving model to ./model_4.0_chkp\weights.182-1.10.hdf5
# Epoch 183/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3906 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00183: ReduceLROnPlateau reducing learning rate to 1.0000000490448793e-21.
#
# Epoch 00183: saving model to ./model_4.0_chkp\weights.183-1.10.hdf5
# Epoch 184/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3053 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00184: saving model to ./model_4.0_chkp\weights.184-1.10.hdf5
# Epoch 185/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0992 - acc: 0.3288 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00185: saving model to ./model_4.0_chkp\weights.185-1.10.hdf5
# Epoch 186/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0980 - acc: 0.3409 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00186: saving model to ./model_4.0_chkp\weights.186-1.10.hdf5
# Epoch 187/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0986 - acc: 0.3042 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00187: saving model to ./model_4.0_chkp\weights.187-1.10.hdf5
# Epoch 188/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3695 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00188: saving model to ./model_4.0_chkp\weights.188-1.10.hdf5
# Epoch 189/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0981 - acc: 0.3551 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00189: saving model to ./model_4.0_chkp\weights.189-1.10.hdf5
# Epoch 190/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0984 - acc: 0.3579 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00190: saving model to ./model_4.0_chkp\weights.190-1.10.hdf5
# Epoch 191/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0985 - acc: 0.3297 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00191: saving model to ./model_4.0_chkp\weights.191-1.10.hdf5
# Epoch 192/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.3361 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00192: saving model to ./model_4.0_chkp\weights.192-1.10.hdf5
# Epoch 193/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0989 - acc: 0.3577 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00193: ReduceLROnPlateau reducing learning rate to 1.0000000692397185e-22.
#
# Epoch 00193: saving model to ./model_4.0_chkp\weights.193-1.10.hdf5
# Epoch 194/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0983 - acc: 0.3328 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00194: saving model to ./model_4.0_chkp\weights.194-1.10.hdf5
# Epoch 195/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0978 - acc: 0.3683 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00195: saving model to ./model_4.0_chkp\weights.195-1.10.hdf5
# Epoch 196/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.1008 - acc: 0.2232 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00196: saving model to ./model_4.0_chkp\weights.196-1.10.hdf5
# Epoch 197/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0978 - acc: 0.3397 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00197: saving model to ./model_4.0_chkp\weights.197-1.10.hdf5
# Epoch 198/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0974 - acc: 0.3834 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00198: saving model to ./model_4.0_chkp\weights.198-1.10.hdf5
# Epoch 199/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0986 - acc: 0.3260 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00199: saving model to ./model_4.0_chkp\weights.199-1.10.hdf5
# Epoch 200/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0989 - acc: 0.3123 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00200: saving model to ./model_4.0_chkp\weights.200-1.10.hdf5
# Epoch 201/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0990 - acc: 0.2924 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00201: saving model to ./model_4.0_chkp\weights.201-1.10.hdf5
# Epoch 202/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0996 - acc: 0.3291 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00202: saving model to ./model_4.0_chkp\weights.202-1.10.hdf5
# Epoch 203/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0991 - acc: 0.3627 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00203: ReduceLROnPlateau reducing learning rate to 1.0000000944832675e-23.
#
# Epoch 00203: saving model to ./model_4.0_chkp\weights.203-1.10.hdf5
# Epoch 204/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0996 - acc: 0.3042 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00204: saving model to ./model_4.0_chkp\weights.204-1.10.hdf5
# Epoch 205/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3327 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00205: saving model to ./model_4.0_chkp\weights.205-1.10.hdf5
# Epoch 206/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0990 - acc: 0.2888 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00206: saving model to ./model_4.0_chkp\weights.206-1.10.hdf5
# Epoch 207/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3336 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00207: saving model to ./model_4.0_chkp\weights.207-1.10.hdf5
# Epoch 208/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0979 - acc: 0.3242 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00208: saving model to ./model_4.0_chkp\weights.208-1.10.hdf5
# Epoch 209/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3004 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00209: saving model to ./model_4.0_chkp\weights.209-1.10.hdf5
# Epoch 210/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3287 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00210: saving model to ./model_4.0_chkp\weights.210-1.10.hdf5
# Epoch 211/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0978 - acc: 0.3819 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00211: saving model to ./model_4.0_chkp\weights.211-1.10.hdf5
# Epoch 212/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0980 - acc: 0.3248 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00212: saving model to ./model_4.0_chkp\weights.212-1.10.hdf5
# Epoch 213/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0992 - acc: 0.2973 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00213: ReduceLROnPlateau reducing learning rate to 1.0000000787060494e-24.
#
# Epoch 00213: saving model to ./model_4.0_chkp\weights.213-1.10.hdf5
# Epoch 214/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3734 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00214: saving model to ./model_4.0_chkp\weights.214-1.10.hdf5
# Epoch 215/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0991 - acc: 0.3150 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00215: saving model to ./model_4.0_chkp\weights.215-1.10.hdf5
# Epoch 216/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0998 - acc: 0.3236 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00216: saving model to ./model_4.0_chkp\weights.216-1.10.hdf5
# Epoch 217/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0986 - acc: 0.3357 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00217: saving model to ./model_4.0_chkp\weights.217-1.10.hdf5
# Epoch 218/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0994 - acc: 0.3016 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00218: saving model to ./model_4.0_chkp\weights.218-1.10.hdf5
# Epoch 219/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0984 - acc: 0.3933 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00219: saving model to ./model_4.0_chkp\weights.219-1.10.hdf5
# Epoch 220/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0979 - acc: 0.3450 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00220: saving model to ./model_4.0_chkp\weights.220-1.10.hdf5
# Epoch 221/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0986 - acc: 0.3651 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00221: saving model to ./model_4.0_chkp\weights.221-1.10.hdf5
# Epoch 222/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3344 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00222: saving model to ./model_4.0_chkp\weights.222-1.10.hdf5
# Epoch 223/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0974 - acc: 0.3975 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00223: ReduceLROnPlateau reducing learning rate to 1.0000001181490946e-25.
#
# Epoch 00223: saving model to ./model_4.0_chkp\weights.223-1.10.hdf5
# Epoch 224/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3161 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00224: saving model to ./model_4.0_chkp\weights.224-1.10.hdf5
# Epoch 225/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3499 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00225: saving model to ./model_4.0_chkp\weights.225-1.10.hdf5
# Epoch 226/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0986 - acc: 0.3586 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00226: saving model to ./model_4.0_chkp\weights.226-1.10.hdf5
# Epoch 227/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3342 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00227: saving model to ./model_4.0_chkp\weights.227-1.10.hdf5
# Epoch 228/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0990 - acc: 0.3720 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00228: saving model to ./model_4.0_chkp\weights.228-1.10.hdf5
# Epoch 229/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0993 - acc: 0.2802 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00229: saving model to ./model_4.0_chkp\weights.229-1.10.hdf5
# Epoch 230/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0998 - acc: 0.2944 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00230: saving model to ./model_4.0_chkp\weights.230-1.10.hdf5
# Epoch 231/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0982 - acc: 0.3369 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00231: saving model to ./model_4.0_chkp\weights.231-1.10.hdf5
# Epoch 232/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0976 - acc: 0.3710 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00232: saving model to ./model_4.0_chkp\weights.232-1.10.hdf5
# Epoch 233/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0982 - acc: 0.3563 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00233: ReduceLROnPlateau reducing learning rate to 1.0000001428009978e-26.
#
# Epoch 00233: saving model to ./model_4.0_chkp\weights.233-1.10.hdf5
# Epoch 234/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0986 - acc: 0.4060 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00234: saving model to ./model_4.0_chkp\weights.234-1.10.hdf5
# Epoch 235/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0972 - acc: 0.3421 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00235: saving model to ./model_4.0_chkp\weights.235-1.10.hdf5
# Epoch 236/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0982 - acc: 0.3347 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00236: saving model to ./model_4.0_chkp\weights.236-1.10.hdf5
# Epoch 237/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3215 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00237: saving model to ./model_4.0_chkp\weights.237-1.10.hdf5
# Epoch 238/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0982 - acc: 0.3459 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00238: saving model to ./model_4.0_chkp\weights.238-1.10.hdf5
# Epoch 239/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3321 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00239: saving model to ./model_4.0_chkp\weights.239-1.10.hdf5
# Epoch 240/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0988 - acc: 0.3404 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00240: saving model to ./model_4.0_chkp\weights.240-1.10.hdf5
# Epoch 241/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0979 - acc: 0.3731 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00241: saving model to ./model_4.0_chkp\weights.241-1.10.hdf5
# Epoch 242/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3282 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00242: saving model to ./model_4.0_chkp\weights.242-1.10.hdf5
# Epoch 243/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3606 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00243: ReduceLROnPlateau reducing learning rate to 1.000000142800998e-27.
#
# Epoch 00243: saving model to ./model_4.0_chkp\weights.243-1.10.hdf5
# Epoch 244/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0996 - acc: 0.3121 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00244: saving model to ./model_4.0_chkp\weights.244-1.10.hdf5
# Epoch 245/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.1004 - acc: 0.2865 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00245: saving model to ./model_4.0_chkp\weights.245-1.10.hdf5
# Epoch 246/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0990 - acc: 0.3472 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00246: saving model to ./model_4.0_chkp\weights.246-1.10.hdf5
# Epoch 247/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3211 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00247: saving model to ./model_4.0_chkp\weights.247-1.10.hdf5
# Epoch 248/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0995 - acc: 0.3323 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00248: saving model to ./model_4.0_chkp\weights.248-1.10.hdf5
# Epoch 249/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0981 - acc: 0.3707 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00249: saving model to ./model_4.0_chkp\weights.249-1.10.hdf5
# Epoch 250/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0991 - acc: 0.3183 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00250: saving model to ./model_4.0_chkp\weights.250-1.10.hdf5
# Epoch 251/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0989 - acc: 0.3080 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00251: saving model to ./model_4.0_chkp\weights.251-1.10.hdf5
# Epoch 252/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0980 - acc: 0.3503 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00252: saving model to ./model_4.0_chkp\weights.252-1.10.hdf5
# Epoch 253/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0994 - acc: 0.3360 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00253: ReduceLROnPlateau reducing learning rate to 1.0000001235416984e-28.
#
# Epoch 00253: saving model to ./model_4.0_chkp\weights.253-1.10.hdf5
# Epoch 254/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0992 - acc: 0.3086 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00254: saving model to ./model_4.0_chkp\weights.254-1.10.hdf5
# Epoch 255/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3433 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00255: saving model to ./model_4.0_chkp\weights.255-1.10.hdf5
# Epoch 256/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0993 - acc: 0.2968 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00256: saving model to ./model_4.0_chkp\weights.256-1.10.hdf5
# Epoch 257/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0980 - acc: 0.3713 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00257: saving model to ./model_4.0_chkp\weights.257-1.10.hdf5
# Epoch 258/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0985 - acc: 0.3615 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00258: saving model to ./model_4.0_chkp\weights.258-1.10.hdf5
# Epoch 259/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0999 - acc: 0.2445 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00259: saving model to ./model_4.0_chkp\weights.259-1.10.hdf5
# Epoch 260/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0980 - acc: 0.3501 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00260: saving model to ./model_4.0_chkp\weights.260-1.10.hdf5
# Epoch 261/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.1003 - acc: 0.2867 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00261: saving model to ./model_4.0_chkp\weights.261-1.10.hdf5
# Epoch 262/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0983 - acc: 0.3523 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00262: saving model to ./model_4.0_chkp\weights.262-1.10.hdf5
# Epoch 263/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0989 - acc: 0.3355 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00263: ReduceLROnPlateau reducing learning rate to 1.0000001235416985e-29.
#
# Epoch 00263: saving model to ./model_4.0_chkp\weights.263-1.10.hdf5
# Epoch 264/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3284 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00264: saving model to ./model_4.0_chkp\weights.264-1.10.hdf5
# Epoch 265/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0991 - acc: 0.3117 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00265: saving model to ./model_4.0_chkp\weights.265-1.10.hdf5
# Epoch 266/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0990 - acc: 0.3188 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00266: saving model to ./model_4.0_chkp\weights.266-1.10.hdf5
# Epoch 267/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0995 - acc: 0.3237 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00267: saving model to ./model_4.0_chkp\weights.267-1.10.hdf5
# Epoch 268/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0985 - acc: 0.3474 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00268: saving model to ./model_4.0_chkp\weights.268-1.10.hdf5
# Epoch 269/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0987 - acc: 0.3144 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00269: saving model to ./model_4.0_chkp\weights.269-1.10.hdf5
# Epoch 270/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1004 - acc: 0.2743 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00270: saving model to ./model_4.0_chkp\weights.270-1.10.hdf5
# Epoch 271/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.1001 - acc: 0.2792 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00271: saving model to ./model_4.0_chkp\weights.271-1.10.hdf5
# Epoch 272/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0980 - acc: 0.3760 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00272: saving model to ./model_4.0_chkp\weights.272-1.10.hdf5
# Epoch 273/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3372 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00273: ReduceLROnPlateau reducing learning rate to 1.0000001536343539e-30.
#
# Epoch 00273: saving model to ./model_4.0_chkp\weights.273-1.10.hdf5
# Epoch 274/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0977 - acc: 0.3254 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00274: saving model to ./model_4.0_chkp\weights.274-1.10.hdf5
# Epoch 275/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3351 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00275: saving model to ./model_4.0_chkp\weights.275-1.10.hdf5
# Epoch 276/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0994 - acc: 0.3175 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00276: saving model to ./model_4.0_chkp\weights.276-1.10.hdf5
# Epoch 277/300
# 92/92 [==============================] - 6s 66ms/step - loss: 1.0984 - acc: 0.3002 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00277: saving model to ./model_4.0_chkp\weights.277-1.10.hdf5
# Epoch 278/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0975 - acc: 0.3882 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00278: saving model to ./model_4.0_chkp\weights.278-1.10.hdf5
# Epoch 279/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0978 - acc: 0.3490 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00279: saving model to ./model_4.0_chkp\weights.279-1.10.hdf5
# Epoch 280/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0984 - acc: 0.3487 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00280: saving model to ./model_4.0_chkp\weights.280-1.10.hdf5
# Epoch 281/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0980 - acc: 0.3512 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00281: saving model to ./model_4.0_chkp\weights.281-1.10.hdf5
# Epoch 282/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0986 - acc: 0.3513 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00282: saving model to ./model_4.0_chkp\weights.282-1.10.hdf5
# Epoch 283/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0997 - acc: 0.2945 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00283: ReduceLROnPlateau reducing learning rate to 1.000000191250173e-31.
#
# Epoch 00283: saving model to ./model_4.0_chkp\weights.283-1.10.hdf5
# Epoch 284/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0977 - acc: 0.3844 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00284: saving model to ./model_4.0_chkp\weights.284-1.10.hdf5
# Epoch 285/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3374 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00285: saving model to ./model_4.0_chkp\weights.285-1.10.hdf5
# Epoch 286/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0995 - acc: 0.3395 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00286: saving model to ./model_4.0_chkp\weights.286-1.10.hdf5
# Epoch 287/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0984 - acc: 0.3301 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00287: saving model to ./model_4.0_chkp\weights.287-1.10.hdf5
# Epoch 288/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0987 - acc: 0.3187 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00288: saving model to ./model_4.0_chkp\weights.288-1.10.hdf5
# Epoch 289/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0977 - acc: 0.3477 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00289: saving model to ./model_4.0_chkp\weights.289-1.10.hdf5
# Epoch 290/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0979 - acc: 0.3344 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00290: saving model to ./model_4.0_chkp\weights.290-1.10.hdf5
# Epoch 291/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.1001 - acc: 0.2928 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00291: saving model to ./model_4.0_chkp\weights.291-1.10.hdf5
# Epoch 292/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3540 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00292: saving model to ./model_4.0_chkp\weights.292-1.10.hdf5
# Epoch 293/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3317 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00293: ReduceLROnPlateau reducing learning rate to 1.0000002147600601e-32.
#
# Epoch 00293: saving model to ./model_4.0_chkp\weights.293-1.10.hdf5
# Epoch 294/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0990 - acc: 0.3255 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00294: saving model to ./model_4.0_chkp\weights.294-1.10.hdf5
# Epoch 295/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0989 - acc: 0.3190 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00295: saving model to ./model_4.0_chkp\weights.295-1.10.hdf5
# Epoch 296/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0983 - acc: 0.3293 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00296: saving model to ./model_4.0_chkp\weights.296-1.10.hdf5
# Epoch 297/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0991 - acc: 0.3063 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00297: saving model to ./model_4.0_chkp\weights.297-1.10.hdf5
# Epoch 298/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0987 - acc: 0.2947 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00298: saving model to ./model_4.0_chkp\weights.298-1.10.hdf5
# Epoch 299/300
# 92/92 [==============================] - 6s 68ms/step - loss: 1.0990 - acc: 0.3089 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00299: saving model to ./model_4.0_chkp\weights.299-1.10.hdf5
# Epoch 300/300
# 92/92 [==============================] - 6s 67ms/step - loss: 1.0987 - acc: 0.3363 - val_loss: 1.0985 - val_acc: 0.3361
#
# Epoch 00300: saving model to ./model_4.0_chkp\weights.300-1.10.hdf5
