# %% [markdown]
# <img src="files/model_1_outline.png">

# %% [markdown]
# # change log
# ## changing shuffle to False
# ## changing sequence rate 5 -> 20

# %% [markdown]
# sequence generator shape (corrected) (b, n, w, h, c)

# %%
import os
import glob
import keras

# %%
# Load the TensorBoard notebook extension
# %reload_ext tensorboard
import tensorflow as tf
import datetime

# %%
# from patrice's blogpost
from keras_video import VideoFrameGenerator

# %%
classes = ['suture_throws', 'hand_ties', 'thread_cuts']
classes.sort()
print(classes)
# Out:
# ['hand_ties', 'suture_throws', 'thread_cuts']

# %%
# some global params
SIZE = (100, 100) # height and width of frame pxl by pxl
CHANNELS = 3 # RGB or whatever
NBFRAME = 20 # num frames in sequence 
BS = 8 # Batch size

# %%
# pattern to get videos and classes
glob_pattern='../data_v3_model_2.2/model_data/{classname}/*.avi'

# %%
# for data augmentation
data_aug = keras.preprocessing.image.ImageDataGenerator(
    zoom_range=.1,
    horizontal_flip=True,
    rotation_range=8,
    width_shift_range=.2,
    height_shift_range=.2)

# %%
# Create video frame generator
train = VideoFrameGenerator(
    classes=classes, 
    glob_pattern=glob_pattern,
    nb_frames=NBFRAME,
    split_val=.33, 
    shuffle=False,
    batch_size=BS,
    target_shape=SIZE,
    nb_channel=CHANNELS,
    use_frame_cache=True)
# Out:
# class hand_ties, validation count: 121, train count: 247
# class suture_throws, validation count: 122, train count: 248
# class thread_cuts, validation count: 121, train count: 248
# Total data: 3 classes for 743 files for train

# %%
# getting validation data
valid = train.get_validation_generator()
# Out:
# Total data: 3 classes for 364 files for validation

# %%
# import keras_video.utils
# keras_video.utils.show_sample(train)

# %%
#valid.files

# %% [markdown]
# ## BUILD CONV NET

# %%
from keras.layers import Conv2D, BatchNormalization, \
    MaxPool2D, GlobalMaxPool2D
def build_mobilenet(shape=(224, 224, 3), nbout=3):
    model = keras.applications.mobilenet.MobileNet(
        include_top=False,
        input_shape=shape,
        weights='imagenet')
    # Keep 9 layers to train﻿﻿
    trainable = 9
    for layer in model.layers[:-trainable]:
        layer.trainable = False
    for layer in model.layers[-trainable:]:
        layer.trainable = True
    output = GlobalMaxPool2D()
    return keras.Sequential([model, output])

# %% [markdown]
# ## Build GRU

# %%
from keras.layers import TimeDistributed, GRU, Dense, Dropout
# Shape (5, 112, 112, 3) 5 - time sequence length 112x112 = height vs width 3 - num channels
def action_model(shape=(5, 112, 112, 3), nbout=3):
    # Create our convnet with (112, 112, 3) input shape
    convnet = build_mobilenet(shape[1:])
    
    # then create our final model
    model = keras.Sequential()
    # add the convnet with (5, 112, 112, 3) shape
    # KEY = allows you to add a time sequence to a layer one at a time
    model.add(TimeDistributed(convnet, input_shape=shape))
    # here, you can also use GRU or LSTM
    model.add(GRU(64))
    # and finally, we make a decision network
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(nbout, activation='softmax'))
    return model

# %% [markdown]
# ## this is where you tell the model how to train - loss function, weight update mechanism

# %%
INSHAPE=(NBFRAME,) + SIZE + (CHANNELS,) # (5, 112, 112, 3)
# action model - GRU set up for Time shifted CNN
model = action_model(INSHAPE, len(classes))

# this is where you tell the model how to train - loss function, weight update mechanism
optimizer = keras.optimizers.Adam(0.001)
model.compile(
    optimizer,
    'categorical_crossentropy',
    metrics=['acc']
)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %% [markdown]
# ## epochs, call backs

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
print('logs for this run are here: {}'.format(log_dir))
# Out:
# logs for this run are here: logs/fit/20210428-232142

# %%
EPOCHS=100
# create a "chkp" directory before to run that
# because ModelCheckpoint will write models inside
callbacks = [
    keras.callbacks.ReduceLROnPlateau(verbose=1),
    keras.callbacks.ModelCheckpoint(
        'model2_3_1_chkp/weights.{epoch:02d}-{val_loss:.2f}.hdf5',
        verbose=1),
    tensorboard_callback
]

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
model.fit(
    train,
    validation_data=valid,
    verbose=1,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 405s 4s/step - loss: 1.2195 - acc: 0.3115 - val_loss: 1.0956 - val_acc: 0.3389
#
# Epoch 00001: saving model to model2_3_1_chkp\weights.01-1.10.hdf5
# Epoch 2/100
# 92/92 [==============================] - 98s 1s/step - loss: 1.1098 - acc: 0.3985 - val_loss: 1.0988 - val_acc: 0.3306
#
# Epoch 00002: saving model to model2_3_1_chkp\weights.02-1.10.hdf5
# Epoch 3/100
# 92/92 [==============================] - 101s 1s/step - loss: 1.1121 - acc: 0.2911 - val_loss: 1.1004 - val_acc: 0.3389
#
# Epoch 00003: saving model to model2_3_1_chkp\weights.03-1.10.hdf5
# Epoch 4/100
# 92/92 [==============================] - 100s 1s/step - loss: 1.1079 - acc: 0.3289 - val_loss: 1.0995 - val_acc: 0.3556
#
# Epoch 00004: saving model to model2_3_1_chkp\weights.04-1.10.hdf5
# Epoch 5/100
# 92/92 [==============================] - 101s 1s/step - loss: 1.1111 - acc: 0.3454 - val_loss: 1.0980 - val_acc: 0.3111
#
# Epoch 00005: saving model to model2_3_1_chkp\weights.05-1.10.hdf5
# Epoch 6/100
# 92/92 [==============================] - 95s 1s/step - loss: 1.1007 - acc: 0.3271 - val_loss: 1.0988 - val_acc: 0.3250
#
# Epoch 00006: saving model to model2_3_1_chkp\weights.06-1.10.hdf5
# Epoch 7/100
# 92/92 [==============================] - 34871s 383s/step - loss: 1.1110 - acc: 0.2928 - val_loss: 1.1006 - val_acc: 0.3389
#
# Epoch 00007: saving model to model2_3_1_chkp\weights.07-1.10.hdf5
# Epoch 8/100
# 92/92 [==============================] - 101s 1s/step - loss: 1.1174 - acc: 0.2630 - val_loss: 1.0993 - val_acc: 0.3389
#
# Epoch 00008: saving model to model2_3_1_chkp\weights.08-1.10.hdf5
# Epoch 9/100
# 92/92 [==============================] - 97s 1s/step - loss: 1.1200 - acc: 0.2902 - val_loss: 1.0994 - val_acc: 0.3250
#
# Epoch 00009: saving model to model2_3_1_chkp\weights.09-1.10.hdf5
# Epoch 10/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.1080 - acc: 0.3073 - val_loss: 1.0986 - val_acc: 0.3389
#
# Epoch 00010: saving model to model2_3_1_chkp\weights.10-1.10.hdf5
# Epoch 11/100
# 92/92 [==============================] - 96s 1s/step - loss: 1.1049 - acc: 0.3419 - val_loss: 1.0990 - val_acc: 0.3389
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00011: saving model to model2_3_1_chkp\weights.11-1.10.hdf5
# Epoch 12/100
# 92/92 [==============================] - 93s 1s/step - loss: 1.0972 - acc: 0.3520 - val_loss: 1.0988 - val_acc: 0.3389
#
# Epoch 00012: saving model to model2_3_1_chkp\weights.12-1.10.hdf5
# Epoch 13/100
# 92/92 [==============================] - 94s 1s/step - loss: 1.0964 - acc: 0.4018 - val_loss: 1.0986 - val_acc: 0.3389
#
# Epoch 00013: saving model to model2_3_1_chkp\weights.13-1.10.hdf5
# Epoch 14/100
# 92/92 [==============================] - 99s 1s/step - loss: 1.0986 - acc: 0.3380 - val_loss: 1.0984 - val_acc: 0.3389
#
# Epoch 00014: saving model to model2_3_1_chkp\weights.14-1.10.hdf5
# Epoch 15/100
# 92/92 [==============================] - 100s 1s/step - loss: 1.0939 - acc: 0.4124 - val_loss: 1.0984 - val_acc: 0.3389
#
# Epoch 00015: saving model to model2_3_1_chkp\weights.15-1.10.hdf5
# Epoch 16/100
# 92/92 [==============================] - 101s 1s/step - loss: 1.0949 - acc: 0.3597 - val_loss: 1.0977 - val_acc: 0.3389
#
# Epoch 00016: saving model to model2_3_1_chkp\weights.16-1.10.hdf5
# Epoch 17/100
# 92/92 [==============================] - 103s 1s/step - loss: 1.0937 - acc: 0.3660 - val_loss: 1.0955 - val_acc: 0.4083
#
# Epoch 00017: saving model to model2_3_1_chkp\weights.17-1.10.hdf5
# Epoch 18/100
# 92/92 [==============================] - 103s 1s/step - loss: 1.0856 - acc: 0.4542 - val_loss: 1.0916 - val_acc: 0.4972
#
# Epoch 00018: saving model to model2_3_1_chkp\weights.18-1.09.hdf5
# Epoch 19/100
# 92/92 [==============================] - 104s 1s/step - loss: 1.0813 - acc: 0.4041 - val_loss: 1.0842 - val_acc: 0.4139
#
# Epoch 00019: saving model to model2_3_1_chkp\weights.19-1.08.hdf5
# Epoch 20/100
# 92/92 [==============================] - 104s 1s/step - loss: 1.0603 - acc: 0.4483 - val_loss: 1.0647 - val_acc: 0.4722
#
# Epoch 00020: saving model to model2_3_1_chkp\weights.20-1.06.hdf5
# Epoch 21/100
# 92/92 [==============================] - 103s 1s/step - loss: 1.0034 - acc: 0.5611 - val_loss: 1.0043 - val_acc: 0.5500
#
# Epoch 00021: saving model to model2_3_1_chkp\weights.21-1.00.hdf5
# Epoch 22/100
# 92/92 [==============================] - 110s 1s/step - loss: 0.8942 - acc: 0.6183 - val_loss: 0.9522 - val_acc: 0.4917
#
# Epoch 00022: saving model to model2_3_1_chkp\weights.22-0.95.hdf5
# Epoch 23/100
# 92/92 [==============================] - 127s 1s/step - loss: 0.8004 - acc: 0.6256 - val_loss: 0.8918 - val_acc: 0.5194
#
# Epoch 00023: saving model to model2_3_1_chkp\weights.23-0.89.hdf5
# Epoch 24/100
# 92/92 [==============================] - 119s 1s/step - loss: 0.6408 - acc: 0.6922 - val_loss: 1.2291 - val_acc: 0.4056
#
# Epoch 00024: saving model to model2_3_1_chkp\weights.24-1.23.hdf5
# Epoch 25/100
# 92/92 [==============================] - 119s 1s/step - loss: 0.6324 - acc: 0.6719 - val_loss: 0.8341 - val_acc: 0.5361
#
# Epoch 00025: saving model to model2_3_1_chkp\weights.25-0.83.hdf5
# Epoch 26/100
# 92/92 [==============================] - 118s 1s/step - loss: 0.5768 - acc: 0.6961 - val_loss: 0.7588 - val_acc: 0.6444
#
# Epoch 00026: saving model to model2_3_1_chkp\weights.26-0.76.hdf5
# Epoch 27/100
# 92/92 [==============================] - 119s 1s/step - loss: 0.5453 - acc: 0.6958 - val_loss: 0.8741 - val_acc: 0.5667
#
# Epoch 00027: saving model to model2_3_1_chkp\weights.27-0.87.hdf5
# Epoch 28/100
# 92/92 [==============================] - 117s 1s/step - loss: 0.5031 - acc: 0.7594 - val_loss: 0.8877 - val_acc: 0.5278
#
# Epoch 00028: saving model to model2_3_1_chkp\weights.28-0.89.hdf5
# Epoch 29/100
# 92/92 [==============================] - 112s 1s/step - loss: 0.4947 - acc: 0.7654 - val_loss: 0.9459 - val_acc: 0.4944
#
# Epoch 00029: saving model to model2_3_1_chkp\weights.29-0.95.hdf5
# Epoch 30/100
# 92/92 [==============================] - 105s 1s/step - loss: 0.4184 - acc: 0.7828 - val_loss: 0.9799 - val_acc: 0.5750
#
# Epoch 00030: saving model to model2_3_1_chkp\weights.30-0.98.hdf5
# Epoch 31/100
# 92/92 [==============================] - 105s 1s/step - loss: 0.4850 - acc: 0.7583 - val_loss: 1.1427 - val_acc: 0.5528
#
# Epoch 00031: saving model to model2_3_1_chkp\weights.31-1.14.hdf5
# Epoch 32/100
# 92/92 [==============================] - 103s 1s/step - loss: 0.4677 - acc: 0.7755 - val_loss: 1.2535 - val_acc: 0.5361
#
# Epoch 00032: saving model to model2_3_1_chkp\weights.32-1.25.hdf5
# Epoch 33/100
# 92/92 [==============================] - 106s 1s/step - loss: 0.4451 - acc: 0.7827 - val_loss: 1.2629 - val_acc: 0.5333
#
# Epoch 00033: saving model to model2_3_1_chkp\weights.33-1.26.hdf5
# Epoch 34/100
# 92/92 [==============================] - 101s 1s/step - loss: 0.3519 - acc: 0.8704 - val_loss: 1.0743 - val_acc: 0.5528
#
# Epoch 00034: saving model to model2_3_1_chkp\weights.34-1.07.hdf5
# Epoch 35/100
# 92/92 [==============================] - 97s 1s/step - loss: 0.3254 - acc: 0.8778 - val_loss: 1.2455 - val_acc: 0.5667
#
# Epoch 00035: saving model to model2_3_1_chkp\weights.35-1.25.hdf5
# Epoch 36/100
# 92/92 [==============================] - 97s 1s/step - loss: 0.2988 - acc: 0.8895 - val_loss: 1.2212 - val_acc: 0.5583
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00036: saving model to model2_3_1_chkp\weights.36-1.22.hdf5
# Epoch 37/100
# 92/92 [==============================] - 101s 1s/step - loss: 0.2722 - acc: 0.9084 - val_loss: 1.3309 - val_acc: 0.5500
#
# Epoch 00037: saving model to model2_3_1_chkp\weights.37-1.33.hdf5
# Epoch 38/100
# 92/92 [==============================] - 103s 1s/step - loss: 0.2094 - acc: 0.9439 - val_loss: 1.3313 - val_acc: 0.5583
#
# Epoch 00038: saving model to model2_3_1_chkp\weights.38-1.33.hdf5
# Epoch 39/100
# 92/92 [==============================] - 99s 1s/step - loss: 0.2309 - acc: 0.9271 - val_loss: 1.3442 - val_acc: 0.5528
#
# Epoch 00039: saving model to model2_3_1_chkp\weights.39-1.34.hdf5
# Epoch 40/100
# 92/92 [==============================] - 98s 1s/step - loss: 0.2172 - acc: 0.9265 - val_loss: 1.3482 - val_acc: 0.5611
#
# Epoch 00040: saving model to model2_3_1_chkp\weights.40-1.35.hdf5
# Epoch 41/100
# 92/92 [==============================] - 101s 1s/step - loss: 0.2406 - acc: 0.9352 - val_loss: 1.3784 - val_acc: 0.5528
#
# Epoch 00041: saving model to model2_3_1_chkp\weights.41-1.38.hdf5
# Epoch 42/100
# 92/92 [==============================] - 100s 1s/step - loss: 0.2195 - acc: 0.9301 - val_loss: 1.3613 - val_acc: 0.5472
#
# Epoch 00042: saving model to model2_3_1_chkp\weights.42-1.36.hdf5
# Epoch 43/100
# 92/92 [==============================] - 100s 1s/step - loss: 0.2159 - acc: 0.9412 - val_loss: 1.3825 - val_acc: 0.5472
#
# Epoch 00043: saving model to model2_3_1_chkp\weights.43-1.38.hdf5
# Epoch 44/100
# 92/92 [==============================] - 102s 1s/step - loss: 0.2238 - acc: 0.9437 - val_loss: 1.3677 - val_acc: 0.5500
#
# Epoch 00044: saving model to model2_3_1_chkp\weights.44-1.37.hdf5
# Epoch 45/100
# 92/92 [==============================] - 101s 1s/step - loss: 0.2342 - acc: 0.9276 - val_loss: 1.3902 - val_acc: 0.5500
#
# Epoch 00045: saving model to model2_3_1_chkp\weights.45-1.39.hdf5
# Epoch 46/100
# 92/92 [==============================] - 98s 1s/step - loss: 0.1852 - acc: 0.9629 - val_loss: 1.5027 - val_acc: 0.5222
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00046: saving model to model2_3_1_chkp\weights.46-1.50.hdf5
# Epoch 47/100
# 92/92 [==============================] - 96s 1s/step - loss: 0.1985 - acc: 0.9297 - val_loss: 1.4881 - val_acc: 0.5389
#
# Epoch 00047: saving model to model2_3_1_chkp\weights.47-1.49.hdf5
# Epoch 48/100
# 92/92 [==============================] - 98s 1s/step - loss: 0.2096 - acc: 0.9399 - val_loss: 1.4048 - val_acc: 0.5500
#
# Epoch 00048: saving model to model2_3_1_chkp\weights.48-1.40.hdf5
# Epoch 49/100
# 92/92 [==============================] - 100s 1s/step - loss: 0.2426 - acc: 0.9221 - val_loss: 1.4565 - val_acc: 0.5472
#
# Epoch 00049: saving model to model2_3_1_chkp\weights.49-1.46.hdf5
# Epoch 50/100
# 92/92 [==============================] - 98s 1s/step - loss: 0.1935 - acc: 0.9571 - val_loss: 1.4593 - val_acc: 0.5500
#
# Epoch 00050: saving model to model2_3_1_chkp\weights.50-1.46.hdf5
# Epoch 51/100
# 92/92 [==============================] - 98s 1s/step - loss: 0.2152 - acc: 0.9449 - val_loss: 1.4113 - val_acc: 0.5500
#
# Epoch 00051: saving model to model2_3_1_chkp\weights.51-1.41.hdf5
# Epoch 52/100
# 92/92 [==============================] - 99s 1s/step - loss: 0.2371 - acc: 0.9208 - val_loss: 1.4805 - val_acc: 0.5444
#
# Epoch 00052: saving model to model2_3_1_chkp\weights.52-1.48.hdf5
# Epoch 53/100
# 92/92 [==============================] - 101s 1s/step - loss: 0.1783 - acc: 0.9422 - val_loss: 1.3989 - val_acc: 0.5556
#
# Epoch 00053: saving model to model2_3_1_chkp\weights.53-1.40.hdf5
# Epoch 54/100
# 92/92 [==============================] - 101s 1s/step - loss: 0.2424 - acc: 0.9190 - val_loss: 1.3724 - val_acc: 0.5500
#
# Epoch 00054: saving model to model2_3_1_chkp\weights.54-1.37.hdf5
# Epoch 55/100
# 92/92 [==============================] - 111s 1s/step - loss: 0.1900 - acc: 0.9430 - val_loss: 1.4229 - val_acc: 0.5472
#
# Epoch 00055: saving model to model2_3_1_chkp\weights.55-1.42.hdf5
# Epoch 56/100
# 92/92 [==============================] - 104s 1s/step - loss: 0.2106 - acc: 0.9351 - val_loss: 1.4488 - val_acc: 0.5472
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00056: saving model to model2_3_1_chkp\weights.56-1.45.hdf5
# Epoch 57/100
# 92/92 [==============================] - 115s 1s/step - loss: 0.1582 - acc: 0.9636 - val_loss: 1.4536 - val_acc: 0.5472
#
# Epoch 00057: saving model to model2_3_1_chkp\weights.57-1.45.hdf5
# Epoch 58/100
# 92/92 [==============================] - 110s 1s/step - loss: 0.1863 - acc: 0.9548 - val_loss: 1.4228 - val_acc: 0.5389
#
# Epoch 00058: saving model to model2_3_1_chkp\weights.58-1.42.hdf5
# Epoch 59/100
# 92/92 [==============================] - 96s 1s/step - loss: 0.2111 - acc: 0.9262 - val_loss: 1.4018 - val_acc: 0.5444
#
# Epoch 00059: saving model to model2_3_1_chkp\weights.59-1.40.hdf5
# Epoch 60/100
# 92/92 [==============================] - 97s 1s/step - loss: 0.1811 - acc: 0.9503 - val_loss: 1.4004 - val_acc: 0.5472
#
# Epoch 00060: saving model to model2_3_1_chkp\weights.60-1.40.hdf5
# Epoch 61/100
# 92/92 [==============================] - 92s 999ms/step - loss: 0.1935 - acc: 0.9485 - val_loss: 1.4278 - val_acc: 0.5528
#
# Epoch 00061: saving model to model2_3_1_chkp\weights.61-1.43.hdf5
# Epoch 62/100
# 92/92 [==============================] - 91s 992ms/step - loss: 0.1701 - acc: 0.9426 - val_loss: 1.4088 - val_acc: 0.5444
#
# Epoch 00062: saving model to model2_3_1_chkp\weights.62-1.41.hdf5
# Epoch 63/100
# 92/92 [==============================] - 93s 1s/step - loss: 0.1764 - acc: 0.9583 - val_loss: 1.4727 - val_acc: 0.5500
#
# Epoch 00063: saving model to model2_3_1_chkp\weights.63-1.47.hdf5
# Epoch 64/100
# 92/92 [==============================] - 91s 994ms/step - loss: 0.2047 - acc: 0.9431 - val_loss: 1.4506 - val_acc: 0.5444
#
# Epoch 00064: saving model to model2_3_1_chkp\weights.64-1.45.hdf5
# Epoch 65/100
# 92/92 [==============================] - 92s 1s/step - loss: 0.1951 - acc: 0.9528 - val_loss: 1.4087 - val_acc: 0.5500
#
# Epoch 00065: saving model to model2_3_1_chkp\weights.65-1.41.hdf5
# Epoch 66/100
# 92/92 [==============================] - 92s 1s/step - loss: 0.1725 - acc: 0.9591 - val_loss: 1.4634 - val_acc: 0.5500
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00066: saving model to model2_3_1_chkp\weights.66-1.46.hdf5
# Epoch 67/100
# 92/92 [==============================] - 96s 1s/step - loss: 0.1831 - acc: 0.9525 - val_loss: 1.4027 - val_acc: 0.5472
#
# Epoch 00067: saving model to model2_3_1_chkp\weights.67-1.40.hdf5
# Epoch 68/100
# 92/92 [==============================] - 106s 1s/step - loss: 0.1729 - acc: 0.9439 - val_loss: 1.3965 - val_acc: 0.5500
#
# Epoch 00068: saving model to model2_3_1_chkp\weights.68-1.40.hdf5
# Epoch 69/100
# 92/92 [==============================] - 92s 1s/step - loss: 0.1878 - acc: 0.9482 - val_loss: 1.4066 - val_acc: 0.5472
#
# Epoch 00069: saving model to model2_3_1_chkp\weights.69-1.41.hdf5
# Epoch 70/100
# 92/92 [==============================] - 92s 1s/step - loss: 0.2406 - acc: 0.9252 - val_loss: 1.4394 - val_acc: 0.5500
#
# Epoch 00070: saving model to model2_3_1_chkp\weights.70-1.44.hdf5
# Epoch 71/100
# 92/92 [==============================] - 92s 1s/step - loss: 0.1844 - acc: 0.9432 - val_loss: 1.4424 - val_acc: 0.5444
#
# Epoch 00071: saving model to model2_3_1_chkp\weights.71-1.44.hdf5
# Epoch 72/100
# 92/92 [==============================] - 91s 993ms/step - loss: 0.1782 - acc: 0.9553 - val_loss: 1.4223 - val_acc: 0.5528
#
# Epoch 00072: saving model to model2_3_1_chkp\weights.72-1.42.hdf5
# Epoch 73/100
# 92/92 [==============================] - 92s 998ms/step - loss: 0.2062 - acc: 0.9224 - val_loss: 1.4279 - val_acc: 0.5444
#
# Epoch 00073: saving model to model2_3_1_chkp\weights.73-1.43.hdf5
# Epoch 74/100
# 92/92 [==============================] - 91s 994ms/step - loss: 0.2288 - acc: 0.9320 - val_loss: 1.4651 - val_acc: 0.5444
#
# Epoch 00074: saving model to model2_3_1_chkp\weights.74-1.47.hdf5
# Epoch 75/100
# 92/92 [==============================] - 101s 1s/step - loss: 0.2192 - acc: 0.9347 - val_loss: 1.4038 - val_acc: 0.5472
#
# Epoch 00075: saving model to model2_3_1_chkp\weights.75-1.40.hdf5
# Epoch 76/100
# 92/92 [==============================] - 105s 1s/step - loss: 0.1768 - acc: 0.9560 - val_loss: 1.3909 - val_acc: 0.5500
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
#
# Epoch 00076: saving model to model2_3_1_chkp\weights.76-1.39.hdf5
# Epoch 77/100
# 92/92 [==============================] - 94s 1s/step - loss: 0.1934 - acc: 0.9399 - val_loss: 1.4417 - val_acc: 0.5444
#
# Epoch 00077: saving model to model2_3_1_chkp\weights.77-1.44.hdf5
# Epoch 78/100
# 92/92 [==============================] - 95s 1s/step - loss: 0.2387 - acc: 0.9200 - val_loss: 1.4546 - val_acc: 0.5472
#
# Epoch 00078: saving model to model2_3_1_chkp\weights.78-1.45.hdf5
# Epoch 79/100
# 92/92 [==============================] - 94s 1s/step - loss: 0.1831 - acc: 0.9475 - val_loss: 1.4329 - val_acc: 0.5472
#
# Epoch 00079: saving model to model2_3_1_chkp\weights.79-1.43.hdf5
# Epoch 80/100
# 92/92 [==============================] - 99s 1s/step - loss: 0.1883 - acc: 0.9402 - val_loss: 1.4674 - val_acc: 0.5583
#
# Epoch 00080: saving model to model2_3_1_chkp\weights.80-1.47.hdf5
# Epoch 81/100
# 92/92 [==============================] - 93s 1s/step - loss: 0.2061 - acc: 0.9347 - val_loss: 1.4429 - val_acc: 0.5556
#
# Epoch 00081: saving model to model2_3_1_chkp\weights.81-1.44.hdf5
# Epoch 82/100
# 92/92 [==============================] - 93s 1s/step - loss: 0.2031 - acc: 0.9359 - val_loss: 1.4439 - val_acc: 0.5528
#
# Epoch 00082: saving model to model2_3_1_chkp\weights.82-1.44.hdf5
# Epoch 83/100
# 92/92 [==============================] - 91s 997ms/step - loss: 0.2112 - acc: 0.9449 - val_loss: 1.4120 - val_acc: 0.5500
#
# Epoch 00083: saving model to model2_3_1_chkp\weights.83-1.41.hdf5
# Epoch 84/100
# 92/92 [==============================] - 94s 1s/step - loss: 0.2018 - acc: 0.9439 - val_loss: 1.4549 - val_acc: 0.5472
#
# Epoch 00084: saving model to model2_3_1_chkp\weights.84-1.45.hdf5
# Epoch 85/100
# 92/92 [==============================] - 98s 1s/step - loss: 0.1819 - acc: 0.9514 - val_loss: 1.4159 - val_acc: 0.5500
#
# Epoch 00085: saving model to model2_3_1_chkp\weights.85-1.42.hdf5
# Epoch 86/100
# 92/92 [==============================] - 107s 1s/step - loss: 0.1966 - acc: 0.9349 - val_loss: 1.4404 - val_acc: 0.5444
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
#
# Epoch 00086: saving model to model2_3_1_chkp\weights.86-1.44.hdf5
# Epoch 87/100
# 92/92 [==============================] - 106s 1s/step - loss: 0.2022 - acc: 0.9303 - val_loss: 1.4420 - val_acc: 0.5444
#
# Epoch 00087: saving model to model2_3_1_chkp\weights.87-1.44.hdf5
# Epoch 88/100
# 92/92 [==============================] - 110s 1s/step - loss: 0.2161 - acc: 0.9462 - val_loss: 1.4264 - val_acc: 0.5472
#
# Epoch 00088: saving model to model2_3_1_chkp\weights.88-1.43.hdf5
# Epoch 89/100
# 92/92 [==============================] - 107s 1s/step - loss: 0.1745 - acc: 0.9468 - val_loss: 1.4534 - val_acc: 0.5472
#
# Epoch 00089: saving model to model2_3_1_chkp\weights.89-1.45.hdf5
# Epoch 90/100
# 92/92 [==============================] - 108s 1s/step - loss: 0.2087 - acc: 0.9541 - val_loss: 1.4857 - val_acc: 0.5528
#
# Epoch 00090: saving model to model2_3_1_chkp\weights.90-1.49.hdf5
# Epoch 91/100
# 92/92 [==============================] - 107s 1s/step - loss: 0.1931 - acc: 0.9465 - val_loss: 1.4334 - val_acc: 0.5444
#
# Epoch 00091: saving model to model2_3_1_chkp\weights.91-1.43.hdf5
# Epoch 92/100
# 92/92 [==============================] - 107s 1s/step - loss: 0.1627 - acc: 0.9587 - val_loss: 1.4607 - val_acc: 0.5583
#
# Epoch 00092: saving model to model2_3_1_chkp\weights.92-1.46.hdf5
# Epoch 93/100
# 92/92 [==============================] - 106s 1s/step - loss: 0.1892 - acc: 0.9437 - val_loss: 1.4239 - val_acc: 0.5500
#
# Epoch 00093: saving model to model2_3_1_chkp\weights.93-1.42.hdf5
# Epoch 94/100
# 92/92 [==============================] - 106s 1s/step - loss: 0.2440 - acc: 0.9164 - val_loss: 1.4389 - val_acc: 0.5528
#
# Epoch 00094: saving model to model2_3_1_chkp\weights.94-1.44.hdf5
# Epoch 95/100
# 92/92 [==============================] - 107s 1s/step - loss: 0.2077 - acc: 0.9326 - val_loss: 1.4527 - val_acc: 0.5528
#
# Epoch 00095: saving model to model2_3_1_chkp\weights.95-1.45.hdf5
# Epoch 96/100
# 92/92 [==============================] - 107s 1s/step - loss: 0.2002 - acc: 0.9396 - val_loss: 1.4593 - val_acc: 0.5500
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
#
# Epoch 00096: saving model to model2_3_1_chkp\weights.96-1.46.hdf5
# Epoch 97/100
# 92/92 [==============================] - 107s 1s/step - loss: 0.1819 - acc: 0.9626 - val_loss: 1.4338 - val_acc: 0.5556
#
# Epoch 00097: saving model to model2_3_1_chkp\weights.97-1.43.hdf5
# Epoch 98/100
# 92/92 [==============================] - 106s 1s/step - loss: 0.1994 - acc: 0.9326 - val_loss: 1.4173 - val_acc: 0.5444
#
# Epoch 00098: saving model to model2_3_1_chkp\weights.98-1.42.hdf5
# Epoch 99/100
# 92/92 [==============================] - 120s 1s/step - loss: 0.2155 - acc: 0.9390 - val_loss: 1.4189 - val_acc: 0.5500
#
# Epoch 00099: saving model to model2_3_1_chkp\weights.99-1.42.hdf5
# Epoch 100/100
# 92/92 [==============================] - 108s 1s/step - loss: 0.2037 - acc: 0.9262 - val_loss: 1.4323 - val_acc: 0.5528
#
# Epoch 00100: saving model to model2_3_1_chkp\weights.100-1.43.hdf5
