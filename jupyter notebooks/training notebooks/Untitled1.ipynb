# %%
from matplotlib import pyplot as plt

# %%
b = ['1.159', '1.128', '1.112', '1.121', '1.098', '1.113', '1.105', '1.099', '1.105', '1.123', '1.094', '1.097', '1.084', '1.105', '1.099', '1.101', '1.098', '1.098', '1.100', '1.096', '1.099', '1.097', '1.100', '1.098', '1.098', '1.099', '1.098', '1.098', '1.098', '1.098', '1.099', '1.098', '1.098', '1.098', '1.098', '1.098', '1.099', '1.098', '1.098', '1.098', '1.099', '1.098', '1.098', '1.098', '1.099', '1.098', '1.099', '1.099', '1.099', '1.098', '1.098', '1.098', '1.098', '1.098', '1.098']

# %%
plt.plot(b)
